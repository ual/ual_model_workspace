# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/home/max/projects/synthpop/scripts/logs/Santa_Clara_County_2018-11-08_19_26_05.447616', header=None, names=['seconds', 'iterations'])
df2 = pd.read_csv('/home/max/projects/synthpop/scripts/logs/Santa_Clara_County_2018-11-08_22_26_19.475045', header=None, names=['seconds', 'iterations'])

# %%
fig, ax = plt.subplots()

sns.scatterplot('iterations', 'seconds', data=df2, ax=ax, label='maxtasksperchild=1')
sns.scatterplot('iterations', 'seconds', data=df, ax=ax, label='maxtasksperchild=None')
ax.legend()
