# %%
import pandas as pd
# import pandana as pdna
import time
import numpy as np
import matplotlib.pyplot as plt
import os

# import matplotlib
# matplotlib.style.use('ggplot')

# %matplotlib inline

pd.options.display.max_columns = 80

# %% [markdown]
# ## Step 1.
# ### Prepare person and place tables.

# %%
os.listdir('/home/data/CHTS_csv_format/data')
# Out:
# ['Deliv_HH.csv',
#  'Deliv_ACTIVITY.csv',
#  'Deliv_LD.csv',
#  'LookUp_LD.csv',
#  'LookUp_Home.csv',
#  'ASSN_TravelDate.csv',
#  'LookUp_PLACE.csv',
#  'LookUp_PER.csv',
#  'Deliv_PER.csv',
#  'Deliv_VEH.csv',
#  'Deliv_PLACE.csv']

# %%
person = pd.read_csv('/home/data/CHTS_csv_format/data/Deliv_PER.csv')

person.head()
# Out:
# /home/emma/anaconda/envs/ual-model/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (40,60,93,97,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      SAMPN  PERNO  RELAT  GEND  AGE  AGEB  HISP  RACE1  RACE2  RACE3  RACE4  \
# 0  1031985      1      1     1   74   NaN     2    1.0    NaN    NaN    NaN
# 1  1031985      2      2     2   73   NaN     2    1.0    NaN    NaN    NaN
# 2  1032036      1      1     1   46   NaN     2    1.0    NaN    NaN    NaN
# 3  1032036      2      2     2   47   NaN     2    1.0   97.0    NaN    NaN
# 4  1032036      3      3     1   15   NaN     2    1.0   97.0    NaN    NaN
#
#          O_RACE  NTVTY  CNTRY  LIC  USER  TRANS  TPTYP1  TPTYP2  TPTYP3  \
# 0           NaN      1    NaN  1.0   1.0    2.0     NaN     NaN     NaN
# 1           NaN      1    NaN  1.0   1.0    2.0     NaN     NaN     NaN
# 2           NaN      1    NaN  1.0   1.0    2.0     NaN     NaN     NaN
# 3  MULTI-RACIAL      1    NaN  1.0   1.0    2.0     NaN     NaN     NaN
# 4  MULTI-RACIAL      1    NaN  NaN   NaN    NaN     NaN     NaN     NaN
#
#    TPTYP4  TPTYP5  TPTYP6  TPTYP7 O_TPTYP  CLIP1  CLIP2  CLIP3  COMP  MET  \
# 0     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN  NaN
# 1     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN  NaN
# 2     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN  NaN
# 3     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN  NaN
# 4     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN  NaN
#
#    PASSTL  FLEX  EMPLY  WKSTAT O_WKSTAT  JOBS  WLOC   WNAME      WCITY WSTAT  \
# 0     2.0   2.0    2.0     1.0      NaN   NaN   NaN     NaN        NaN   NaN
# 1     2.0   2.0    2.0     1.0      NaN   NaN   NaN     NaN        NaN   NaN
# 2     2.0   2.0    1.0     NaN      NaN   1.0   1.0  HIDDEN  SAN DIEGO    CA
# 3     2.0   2.0    2.0     3.0      NaN   NaN   NaN     NaN        NaN   NaN
# 4     NaN   NaN    NaN     NaN      NaN   NaN   NaN     NaN        NaN   NaN
#
#       ...     HVLOG PTRIPS TOLLF TOLLR1 TOLLR2  TOLLR3  TOLLR4  TOLLR5  \
# 0     ...       1.0    2.0   3.0    NaN    NaN     NaN     NaN     NaN
# 1     ...       1.0    2.0   3.0    NaN    NaN     NaN     NaN     NaN
# 2     ...       NaN    5.0   3.0    NaN    NaN     NaN     NaN     NaN
# 3     ...       NaN   18.0   3.0    NaN    NaN     NaN     NaN     NaN
# 4     ...       NaN    4.0   3.0    NaN    NaN     NaN     NaN     NaN
#
#    TOLLR6  TOLLR7  TOLLR8  TOLLR9  TOLLR10  TOLLB1  TOLLB2  TOLLB3  TOLLB4  \
# 0     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN     NaN
#
#    TOLLB5 TOLLB6  TOLLB7 TOLLB8  TOLLB9 TOLLB10 HOVL NOGOWHY  NOGOWHY_O  \
# 0     NaN    NaN     NaN    NaN     NaN     NaN  2.0     NaN        NaN
# 1     NaN    NaN     NaN    NaN     NaN     NaN  2.0     NaN        NaN
# 2     NaN    NaN     NaN    NaN     NaN     NaN  1.0     NaN        NaN
# 3     NaN    NaN     NaN    NaN     NaN     NaN  1.0     NaN        NaN
# 4     NaN    NaN     NaN    NaN     NaN     NaN  1.0     NaN        NaN
#
#   InComplete Moto_trip  WCTFIP   WTRACT  SCTFIP   STRACT  WPrimaryCity  \
# 0        NaN       1.0     NaN      NaN     NaN      NaN           NaN
# 1        NaN       1.0     NaN      NaN     NaN      NaN           NaN
# 2        NaN       1.0    73.0  17032.0     NaN      NaN     SAN DIEGO
# 3        NaN       1.0     NaN      NaN     NaN      NaN           NaN
# 4        NaN       1.0     NaN      NaN    73.0  17030.0           NaN
#
#    WSTFIP  W2PrimaryCity  W2STFIP  SPrimaryCity SSTFIP    PERWGT   EXPPERWGT
# 0     NaN            NaN      NaN           NaN    NaN  0.052086   17.647568
# 1     NaN            NaN      NaN           NaN    NaN  0.052086   17.647568
# 2     6.0            NaN      NaN           NaN    NaN  1.223974  414.701494
# 3     NaN            NaN      NaN           NaN    NaN  0.863473  292.558373
# 4     NaN            NaN      NaN     SAN DIEGO    6.0  0.941412  318.965100
#
# [5 rows x 148 columns]

# %%
place = pd.read_csv('/home/data/CHTS_csv_format/data/Deliv_PLACE.csv')

place.head()
# Out:
# /home/emma/anaconda/envs/ual-model/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      SAMPN  PERNO  PLANO  TOTTR  HHMEM  PER1  PER2  PER3  PER4  PER5  NONHH  \
# 0  1031985      1      1    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1  1031985      1      2    2.0    0.0   NaN   NaN   NaN   NaN   NaN    1.0
# 2  1031985      1      3    2.0    0.0   NaN   NaN   NaN   NaN   NaN    1.0
# 3  1031985      2      1    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 4  1031985      2      2    1.0    0.0   NaN   NaN   NaN   NaN   NaN    0.0
#
#    MODE  VEHNO  DYGOV  PRKTY O_PRKTY PXSTR  PRKMIN  PAYPK  PKAMT  PKUNT  \
# 0   NaN    NaN    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 1   6.0   97.0    1.0    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 2   6.0   97.0    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 3   NaN    NaN    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 4   5.0    1.0    1.0    1.0     NaN   NaN     NaN    NaN    NaN    NaN
#
#    PRKHW O_PRKHW  EMPARK  TRANSYS O_TRANSYS ROUTE  ACTCNT  ARR_HR  ARR_MIN  \
# 0    NaN     NaN     NaN      NaN       NaN   NaN     3.0       3        0
# 1    NaN     NaN     NaN      NaN       NaN   NaN     1.0       9        2
# 2    NaN     NaN     NaN      NaN       NaN   NaN     3.0      13       13
# 3    NaN     NaN     NaN      NaN       NaN   NaN     3.0       3        0
# 4    NaN     NaN     NaN      NaN       NaN   NaN     1.0       9       26
#
#    DEP_HR  DEP_MIN  TRIPDUR  ACTDUR  TRIPDIST                          PNAME  \
# 0       8       40      NaN     340       NaN                           HOME
# 1      12       53     22.0     231  7.647539  BENICIA SENIOR CITIZEN CENTER
# 2       2       59     20.0     826  7.647539                           HOME
# 3       9       16      NaN     376       NaN                           HOME
# 4      10       43     10.0      77  3.411647   LOMA VISTA ELEMENTARY SCHOOL
#
#       CITY STATE    ZIP   XCORD   YCORD  RouteDistance  CTFIP     TRACT  \
# 0  VALLEJO    CA  94591  HIDDEN  HIDDEN            NaN   95.0  252202.0
# 1  BENICIA    CA  94510  HIDDEN  HIDDEN      13.285837   95.0  960500.0
# 2  VALLEJO    CA  94591  HIDDEN  HIDDEN      12.844300   95.0  252202.0
# 3  VALLEJO    CA  94591  HIDDEN  HIDDEN            NaN   95.0  252202.0
# 4  VALLEJO    CA  94589  HIDDEN  HIDDEN       5.065893   95.0  950200.0
#
#   PPrimaryCity  PSTFIP    PERWGT  EXPPERWGT  TRIPNO       TCF  TCFPERWGT  \
# 0      VALLEJO       6  0.052086  17.647568     NaN       NaN        NaN
# 1      BENICIA       6  0.052086  17.647568     1.0  0.969789   0.050512
# 2      VALLEJO       6  0.052086  17.647568     2.0  1.011905   0.052706
# 3      VALLEJO       6  0.052086  17.647568     NaN       NaN        NaN
# 4      VALLEJO       6  0.052086  17.647568     1.0  1.119681   0.058320
#
#    EXPTCFPERWGT
# 0           NaN
# 1     17.114409
# 2     17.857658
# 3           NaN
# 4     19.759644

# %%
place['HHPER'] = place['SAMPN'].map(str) + place['PERNO'].map(str)

place['HHPERPLA'] = place['HHPER'].map(str) + place['PLANO'].map(str)

# %%
place['ST_num'] = place['ARR_HR'] + (place['ARR_MIN']/60)

place['ET_num'] = place['DEP_HR'] + (place['DEP_MIN']/60)

place.loc[ (place['ST_num'] > 24),
    'ST_num'] = place['ST_num'] - 24

place.loc[ (place['ET_num'] > 24),
    'ET_num'] = place['ET_num'] - 24

# %%
place.head()
# Out:
#      SAMPN  PERNO  PLANO  TOTTR  HHMEM  PER1  PER2  PER3  PER4  PER5  NONHH  \
# 0  1031985      1      1    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1  1031985      1      2    2.0    0.0   NaN   NaN   NaN   NaN   NaN    1.0
# 2  1031985      1      3    2.0    0.0   NaN   NaN   NaN   NaN   NaN    1.0
# 3  1031985      2      1    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 4  1031985      2      2    1.0    0.0   NaN   NaN   NaN   NaN   NaN    0.0
#
#    MODE  VEHNO  DYGOV  PRKTY O_PRKTY PXSTR  PRKMIN  PAYPK  PKAMT  PKUNT  \
# 0   NaN    NaN    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 1   6.0   97.0    1.0    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 2   6.0   97.0    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 3   NaN    NaN    NaN    NaN     NaN   NaN     NaN    NaN    NaN    NaN
# 4   5.0    1.0    1.0    1.0     NaN   NaN     NaN    NaN    NaN    NaN
#
#    PRKHW O_PRKHW  EMPARK  TRANSYS O_TRANSYS ROUTE  ACTCNT  ARR_HR  ARR_MIN  \
# 0    NaN     NaN     NaN      NaN       NaN   NaN     3.0       3        0
# 1    NaN     NaN     NaN      NaN       NaN   NaN     1.0       9        2
# 2    NaN     NaN     NaN      NaN       NaN   NaN     3.0      13       13
# 3    NaN     NaN     NaN      NaN       NaN   NaN     3.0       3        0
# 4    NaN     NaN     NaN      NaN       NaN   NaN     1.0       9       26
#
#    DEP_HR  DEP_MIN  TRIPDUR  ACTDUR  TRIPDIST                          PNAME  \
# 0       8       40      NaN     340       NaN                           HOME
# 1      12       53     22.0     231  7.647539  BENICIA SENIOR CITIZEN CENTER
# 2       2       59     20.0     826  7.647539                           HOME
# 3       9       16      NaN     376       NaN                           HOME
# 4      10       43     10.0      77  3.411647   LOMA VISTA ELEMENTARY SCHOOL
#
#       CITY STATE    ZIP   XCORD   YCORD  RouteDistance  CTFIP     TRACT  \
# 0  VALLEJO    CA  94591  HIDDEN  HIDDEN            NaN   95.0  252202.0
# 1  BENICIA    CA  94510  HIDDEN  HIDDEN      13.285837   95.0  960500.0
# 2  VALLEJO    CA  94591  HIDDEN  HIDDEN      12.844300   95.0  252202.0
# 3  VALLEJO    CA  94591  HIDDEN  HIDDEN            NaN   95.0  252202.0
# 4  VALLEJO    CA  94589  HIDDEN  HIDDEN       5.065893   95.0  950200.0
#
#   PPrimaryCity  PSTFIP    PERWGT  EXPPERWGT  TRIPNO       TCF  TCFPERWGT  \
# 0      VALLEJO       6  0.052086  17.647568     NaN       NaN        NaN
# 1      BENICIA       6  0.052086  17.647568     1.0  0.969789   0.050512
# 2      VALLEJO       6  0.052086  17.647568     2.0  1.011905   0.052706
# 3      VALLEJO       6  0.052086  17.647568     NaN       NaN        NaN
# 4      VALLEJO       6  0.052086  17.647568     1.0  1.119681   0.058320
#
#    EXPTCFPERWGT     HHPER   HHPERPLA     ST_num     ET_num
# 0           NaN  10319851  103198511   3.000000   8.666667
# 1     17.114409  10319851  103198512   9.033333  12.883333
# 2     17.857658  10319851  103198513  13.216667   2.983333
# 3           NaN  10319852  103198521   3.000000   9.266667
# 4     19.759644  10319852  103198522   9.433333  10.716667

# %%
place1 = place[['HHPER','HHPERPLA','MODE','ST_num','ET_num','PNAME']]

# %% [markdown]
# ### Rearrange activities table to allow classifying each location as work, home, or other.

# %%
# activity.STIME.astype(str).str.split(':',expand = True).astype(int).apply(lambda x: x[0]+x[1]/60.,axis = 1)

# %%
activity = pd.read_csv('/home/data/CHTS_csv_format/data/Deliv_ACTIVITY.csv')

activity.head()
# Out:
#      SAMPN  PERNO  PLANO  ACTNO  ACTOTH  ACTHH  ACTOR  ACTWK  ACTSC  ACTRG  \
# 0  1031985      1      1      1     NaN    NaN    NaN    NaN    NaN    NaN
# 1  1031985      1      1      2     NaN    NaN    NaN    NaN    NaN    NaN
# 2  1031985      1      1      3     NaN    NaN    NaN    NaN    NaN    NaN
# 3  1031985      1      2      1     NaN    NaN    NaN    NaN    NaN    NaN
# 4  1031985      1      3      1     NaN    NaN    NaN    NaN    NaN    NaN
#
#    ACTFR  ACTOT  APURP O_APURP  STIME  ETIME    PERWGT  EXPPERWGT  TRIPNO  \
# 0    NaN    NaN      1     NaN  03:00  07:00  0.052086  17.647568     NaN
# 1    NaN    NaN      2     NaN  07:00  08:10  0.052086  17.647568     NaN
# 2    NaN    NaN      1     NaN  08:10  08:40  0.052086  17.647568     NaN
# 3    NaN    NaN     37     NaN  09:02  12:48  0.052086  17.647568     1.0
# 4    NaN    NaN      2     NaN  13:13  13:38  0.052086  17.647568     2.0
#
#         TCF  TCFPERWGT  EXPTCFPERWGT
# 0       NaN        NaN           NaN
# 1       NaN        NaN           NaN
# 2       NaN        NaN           NaN
# 3  0.969789   0.050512     17.114409
# 4  1.011905   0.052706     17.857658

# %%
activity['HHPER'] = activity['SAMPN'].map(str) + activity['PERNO'].map(str)

activity['HHPERPLA'] = activity['HHPER'].map(str) + activity['PLANO'].map(str)

# %%
activity['count'] = activity.groupby('HHPERPLA').cumcount() + 1

activity.head()
# Out:
#      SAMPN  PERNO  PLANO  ACTNO  ACTOTH  ACTHH  ACTOR  ACTWK  ACTSC  ACTRG  \
# 0  1031985      1      1      1     NaN    NaN    NaN    NaN    NaN    NaN
# 1  1031985      1      1      2     NaN    NaN    NaN    NaN    NaN    NaN
# 2  1031985      1      1      3     NaN    NaN    NaN    NaN    NaN    NaN
# 3  1031985      1      2      1     NaN    NaN    NaN    NaN    NaN    NaN
# 4  1031985      1      3      1     NaN    NaN    NaN    NaN    NaN    NaN
#
#    ACTFR  ACTOT  APURP O_APURP  STIME  ETIME    PERWGT  EXPPERWGT  TRIPNO  \
# 0    NaN    NaN      1     NaN  03:00  07:00  0.052086  17.647568     NaN
# 1    NaN    NaN      2     NaN  07:00  08:10  0.052086  17.647568     NaN
# 2    NaN    NaN      1     NaN  08:10  08:40  0.052086  17.647568     NaN
# 3    NaN    NaN     37     NaN  09:02  12:48  0.052086  17.647568     1.0
# 4    NaN    NaN      2     NaN  13:13  13:38  0.052086  17.647568     2.0
#
#         TCF  TCFPERWGT  EXPTCFPERWGT     HHPER   HHPERPLA  count
# 0       NaN        NaN           NaN  10319851  103198511      1
# 1       NaN        NaN           NaN  10319851  103198511      2
# 2       NaN        NaN           NaN  10319851  103198511      3
# 3  0.969789   0.050512     17.114409  10319851  103198512      1
# 4  1.011905   0.052706     17.857658  10319851  103198513      1

# %%
activity2 = activity.pivot(index='HHPERPLA', columns='count', values='APURP').reset_index()

activity2.columns = ['HHPERPLA', 'APURP1', 'APURP2', 'APURP3']

activity2.head()
# Out:
#     HHPERPLA  APURP1  APURP2  APURP3
# 0  103198511     1.0     2.0     1.0
# 1  103198512    37.0     NaN     NaN
# 2  103198513     2.0     7.0     8.0
# 3  103198521     1.0     2.0     7.0
# 4  103198522    33.0     NaN     NaN

# %% [markdown]
# ### Classify locations as work or not.

# %%
activity2['place'] = np.where(((activity2['APURP1'] == 9) | (activity2['APURP1'] == 10) | (activity2['APURP1'] == 16) |
                             (activity2['APURP2'] == 9) |(activity2['APURP2'] == 10) |(activity2['APURP2'] == 16) |
                             (activity2['APURP3'] == 9) |(activity2['APURP3'] == 10) |(activity2['APURP3'] == 16)), 'work', 'no')

activity2.head()
# Out:
#     HHPERPLA  APURP1  APURP2  APURP3 place
# 0  103198511     1.0     2.0     1.0    no
# 1  103198512    37.0     NaN     NaN    no
# 2  103198513     2.0     7.0     8.0    no
# 3  103198521     1.0     2.0     7.0    no
# 4  103198522    33.0     NaN     NaN    no

# %% [markdown]
# ### Classify locations as home.

# %%
place2 = pd.merge(place1, activity2, on='HHPERPLA')

place2.loc[place2.PNAME == "HOME", 'place'] = "home"

place2.head()
# Out:
#       HHPER   HHPERPLA  MODE     ST_num     ET_num  \
# 0  10319851  103198511   NaN   3.000000   8.666667
# 1  10319851  103198512   6.0   9.033333  12.883333
# 2  10319851  103198513   6.0  13.216667   2.983333
# 3  10319852  103198521   NaN   3.000000   9.266667
# 4  10319852  103198522   5.0   9.433333  10.716667
#
#                            PNAME  APURP1  APURP2  APURP3 place
# 0                           HOME     1.0     2.0     1.0  home
# 1  BENICIA SENIOR CITIZEN CENTER    37.0     NaN     NaN    no
# 2                           HOME     2.0     7.0     8.0  home
# 3                           HOME     1.0     2.0     7.0  home
# 4   LOMA VISTA ELEMENTARY SCHOOL    33.0     NaN     NaN    no

# %% [markdown]
# ### Assign XY coordinates and zones to home and work locations.

# %%
od = pd.read_csv("/home/data/fall_2018/chts_persons_w_zone_ids.csv")

od.head()
# Out:
# /home/emma/anaconda/envs/ual-model/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (42,95,99,106,152,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  index    SAMPN  PERNO  RELAT  GEND  AGE  AGEB  HISP  RACE1  \
# 0           0      0  1031985      1      1     1   74   NaN     2    1.0
# 1           1      1  1031985      2      2     2   73   NaN     2    1.0
# 2           2     20  1033944      1      1     2   43   NaN     2    1.0
# 3           3     27  1035274      1      1     2   72   NaN     2    1.0
# 4           4     28  1035274      2      2     1   72   NaN     2    1.0
#
#    RACE2  RACE3  RACE4 O_RACE  NTVTY  CNTRY  LIC  USER  TRANS  TPTYP1  TPTYP2  \
# 0    NaN    NaN    NaN    NaN      1    NaN  1.0   1.0    2.0     NaN     NaN
# 1    NaN    NaN    NaN    NaN      1    NaN  1.0   1.0    2.0     NaN     NaN
# 2    2.0    NaN    NaN    NaN      1    NaN  2.0   NaN    1.0     1.0     NaN
# 3    NaN    NaN    NaN    NaN      1    NaN  1.0   1.0    2.0     NaN     NaN
# 4    NaN    NaN    NaN    NaN      1    NaN  1.0   2.0    2.0     NaN     NaN
#
#    TPTYP3  TPTYP4  TPTYP5  TPTYP6  TPTYP7 O_TPTYP  CLIP1  CLIP2  CLIP3  COMP  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN   13.0    NaN    NaN   NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN    NaN   NaN
#
#    MET  PASSTL  FLEX  EMPLY  WKSTAT O_WKSTAT  JOBS  WLOC WNAME_persons  \
# 0  NaN     2.0   2.0    2.0     1.0      NaN   NaN   NaN           NaN
# 1  NaN     2.0   2.0    2.0     1.0      NaN   NaN   NaN           NaN
# 2  NaN     2.0   2.0    1.0     NaN      NaN   1.0   1.0        HIDDEN
# 3  NaN     2.0   2.0    2.0     1.0      NaN   NaN   NaN           NaN
# 4  NaN     2.0   2.0    1.0     NaN      NaN   1.0   1.0        HIDDEN
#
#       ...      WXST1_lookup WXST2_lookup WXCORD_lookup WYCORD_lookup  \
# 0     ...               NaN          NaN           NaN           NaN
# 1     ...               NaN          NaN           NaN           NaN
# 2     ...               NaN          NaN   -122.402606     37.771256
# 3     ...               NaN          NaN           NaN           NaN
# 4     ...               NaN          NaN   -121.664242     37.151629
#
#   WNAME2_lookup WCITY2_lookup WZIP2_lookup  WXST2_1_lookup  WXST2_2_lookup  \
# 0           NaN           NaN          NaN             NaN             NaN
# 1           NaN           NaN          NaN             NaN             NaN
# 2           NaN           NaN          NaN             NaN             NaN
# 3           NaN           NaN          NaN             NaN             NaN
# 4           NaN           NaN          NaN             NaN             NaN
#
#    SNAME_lookup  SCITY_lookup  SZIP_lookup  SXST1_lookup  SXST2_lookup  \
# 0           NaN           NaN          NaN           NaN           NaN
# 1           NaN           NaN          NaN           NaN           NaN
# 2           NaN           NaN          NaN           NaN           NaN
# 3           NaN           NaN          NaN           NaN           NaN
# 4           NaN           NaN          NaN           NaN           NaN
#
#    SXCORD_lookup  SYCORD_lookup  WCTFIP_lookup  WTRACT_lookup        WBLOCK  \
# 0            NaN            NaN            NaN            NaN           NaN
# 1            NaN            NaN            NaN            NaN           NaN
# 2            NaN            NaN           75.0        18000.0  6.075018e+13
# 3            NaN            NaN            NaN            NaN           NaN
# 4            NaN            NaN           85.0       512311.0  6.085512e+13
#
#    WPrimaryCity_lookup WSTFIP_lookup  W2PrimaryCity_lookup W2STFIP_lookup  \
# 0                  NaN           NaN                   NaN            NaN
# 1                  NaN           NaN                   NaN            NaN
# 2        SAN FRANCISCO           6.0                   NaN            NaN
# 3                  NaN           NaN                   NaN            NaN
# 4          MORGAN HILL           6.0                   NaN            NaN
#
#    SCTFIP_lookup STRACT_lookup SBLOCK SPrimaryCity_lookup  SSTFIP_lookup  \
# 0            NaN           NaN    NaN                 NaN            NaN
# 1            NaN           NaN    NaN                 NaN            NaN
# 2            NaN           NaN    NaN                 NaN            NaN
# 3            NaN           NaN    NaN                 NaN            NaN
# 4            NaN           NaN    NaN                 NaN            NaN
#
#            HCITY   HZIP      HXCORD     HYCORD          HBLOCK  HTRACT  \
# 0        VALLEJO  94591 -122.182785  38.161600  60952522021011  252202
# 1        VALLEJO  94591 -122.182785  38.161600  60952522021011  252202
# 2  SAN FRANCISCO  94132 -122.470070  37.718091  60750313012004   31301
# 3      SUNNYVALE  94085 -122.017274  37.388281  60855090004012  509000
# 4      SUNNYVALE  94085 -122.017274  37.388281  60855090004012  509000
#
#    HCTFIP   HPrimaryCity  parcel_id_home  parcel_id_work  zone_id_home  \
# 0      95        VALLEJO         1864693             NaN          1247
# 1      95        VALLEJO         1864693             NaN          1247
# 2      75  SAN FRANCISCO         1031066        982940.0           168
# 3      85      SUNNYVALE         1352587             NaN           424
# 4      85      SUNNYVALE         1352587       1695178.0           424
#
#   zone_id_work
# 0          NaN
# 1          NaN
# 2        108.0
# 3          NaN
# 4        700.0
#
# [5 rows x 193 columns]

# %%
od['HHPER'] = od['SAMPN'].map(str) + od['PERNO'].map(str)

od = od[['HHPER','zone_id_home','zone_id_work','HXCORD','HYCORD','WXCORD_lookup','WYCORD_lookup']]

# %%
place3 = pd.merge(place2, od, on='HHPER')

place3.head()
# Out:
#       HHPER   HHPERPLA  MODE     ST_num     ET_num  \
# 0  10319851  103198511   NaN   3.000000   8.666667
# 1  10319851  103198512   6.0   9.033333  12.883333
# 2  10319851  103198513   6.0  13.216667   2.983333
# 3  10319852  103198521   NaN   3.000000   9.266667
# 4  10319852  103198522   5.0   9.433333  10.716667
#
#                            PNAME  APURP1  APURP2  APURP3 place  zone_id_home  \
# 0                           HOME     1.0     2.0     1.0  home          1247
# 1  BENICIA SENIOR CITIZEN CENTER    37.0     NaN     NaN    no          1247
# 2                           HOME     2.0     7.0     8.0  home          1247
# 3                           HOME     1.0     2.0     7.0  home          1247
# 4   LOMA VISTA ELEMENTARY SCHOOL    33.0     NaN     NaN    no          1247
#
#    zone_id_work      HXCORD   HYCORD  WXCORD_lookup  WYCORD_lookup
# 0           NaN -122.182785  38.1616            NaN            NaN
# 1           NaN -122.182785  38.1616            NaN            NaN
# 2           NaN -122.182785  38.1616            NaN            NaN
# 3           NaN -122.182785  38.1616            NaN            NaN
# 4           NaN -122.182785  38.1616            NaN            NaN

# %%
place3 = place3.loc[~(place3['zone_id_work'].isnull())]

# %%
print (place2.HHPER.nunique())
print (od.HHPER.nunique())
print (place3.HHPER.nunique())
# Out:
# 108778
# 24030
# 10416

# %% [markdown]
# ## Step 2.
# ### Filter for people who go to work at least once during the day.

# %%
#selecting trips by people who go to work at least once

place4 = place3.groupby('HHPER').filter(lambda x : x['place'].isin(["work"]).any())

place4.head()
# Out:
#        HHPER   HHPERPLA  MODE     ST_num     ET_num  \
# 30  10352742  103527421   NaN   3.000000   8.750000
# 31  10352742  103527422   5.0   9.166667  16.750000
# 32  10352742  103527423   5.0  17.083333  17.333333
# 33  10352742  103527424   5.0  17.450000  18.416667
# 34  10352742  103527425   5.0  18.533333  18.750000
#
#                           PNAME  APURP1  APURP2  APURP3 place  zone_id_home  \
# 30                         HOME     1.0     2.0     NaN  home           424
# 31                       EXELIS     9.0    11.0     NaN  work           424
# 32  REGENCY OF EVERGREEN VALLEY    37.0     NaN     NaN    no           424
# 33                          CVS    27.0     NaN     NaN    no           424
# 34  REGENCY OF EVERGREEN VALLEY    37.0     NaN     NaN    no           424
#
#     zone_id_work      HXCORD     HYCORD  WXCORD_lookup  WYCORD_lookup
# 30         700.0 -122.017274  37.388281    -121.664242      37.151629
# 31         700.0 -122.017274  37.388281    -121.664242      37.151629
# 32         700.0 -122.017274  37.388281    -121.664242      37.151629
# 33         700.0 -122.017274  37.388281    -121.664242      37.151629
# 34         700.0 -122.017274  37.388281    -121.664242      37.151629

# %%
print (place2.HHPER.nunique())
print (od.HHPER.nunique())
print (place3.HHPER.nunique())
print (place4.HHPER.nunique())
# Out:
# 108778
# 24030
# 10416
# 6211

# %%
place5 = place4[['HHPER', 'HHPERPLA','place', 'PNAME','ST_num','ET_num','MODE',
                            'zone_id_home','zone_id_work','HXCORD','HYCORD','WXCORD_lookup','WYCORD_lookup']].copy()

place5.head()
# Out:
#        HHPER   HHPERPLA place                        PNAME     ST_num  \
# 30  10352742  103527421  home                         HOME   3.000000
# 31  10352742  103527422  work                       EXELIS   9.166667
# 32  10352742  103527423    no  REGENCY OF EVERGREEN VALLEY  17.083333
# 33  10352742  103527424    no                          CVS  17.450000
# 34  10352742  103527425    no  REGENCY OF EVERGREEN VALLEY  18.533333
#
#        ET_num  MODE  zone_id_home  zone_id_work      HXCORD     HYCORD  \
# 30   8.750000   NaN           424         700.0 -122.017274  37.388281
# 31  16.750000   5.0           424         700.0 -122.017274  37.388281
# 32  17.333333   5.0           424         700.0 -122.017274  37.388281
# 33  18.416667   5.0           424         700.0 -122.017274  37.388281
# 34  18.750000   5.0           424         700.0 -122.017274  37.388281
#
#     WXCORD_lookup  WYCORD_lookup
# 30    -121.664242      37.151629
# 31    -121.664242      37.151629
# 32    -121.664242      37.151629
# 33    -121.664242      37.151629
# 34    -121.664242      37.151629

# %% [markdown]
# ### Change "MODE" column from mode-to to mode-from:

# %%
place5['MODE_NEW'] = place5.groupby('HHPER', group_keys=False).MODE.shift(-1)

place5.head(n=10)
# Out:
#        HHPER   HHPERPLA place                        PNAME     ST_num  \
# 30  10352742  103527421  home                         HOME   3.000000
# 31  10352742  103527422  work                       EXELIS   9.166667
# 32  10352742  103527423    no  REGENCY OF EVERGREEN VALLEY  17.083333
# 33  10352742  103527424    no                          CVS  17.450000
# 34  10352742  103527425    no  REGENCY OF EVERGREEN VALLEY  18.533333
# 35  10352742  103527426  home                         HOME  19.166667
# 65  10414944  104149441  home                         HOME   3.000000
# 66  10414944  104149442  work       INDEPENDENT CONTRACTOR   8.750000
# 67  10414944  104149443  home                         HOME  18.000000
# 68  10417661  104176611  home                         HOME   3.000000
#
#        ET_num  MODE  zone_id_home  zone_id_work      HXCORD     HYCORD  \
# 30   8.750000   NaN           424         700.0 -122.017274  37.388281
# 31  16.750000   5.0           424         700.0 -122.017274  37.388281
# 32  17.333333   5.0           424         700.0 -122.017274  37.388281
# 33  18.416667   5.0           424         700.0 -122.017274  37.388281
# 34  18.750000   5.0           424         700.0 -122.017274  37.388281
# 35   2.983333   5.0           424         700.0 -122.017274  37.388281
# 65   8.500000   NaN          1095        1152.0 -122.091521  38.010760
# 66  17.500000   5.0          1095        1152.0 -122.091521  38.010760
# 67   2.983333   5.0          1095        1152.0 -122.091521  38.010760
# 68   8.000000   NaN           241          69.0 -122.414811  37.610585
#
#     WXCORD_lookup  WYCORD_lookup  MODE_NEW
# 30    -121.664242      37.151629       5.0
# 31    -121.664242      37.151629       5.0
# 32    -121.664242      37.151629       5.0
# 33    -121.664242      37.151629       5.0
# 34    -121.664242      37.151629       5.0
# 35    -121.664242      37.151629       NaN
# 65    -122.118103      37.885783       5.0
# 66    -122.118103      37.885783       5.0
# 67    -122.118103      37.885783       NaN
# 68    -122.447100      37.779020       5.0

# %% [markdown]
# ## Step 3. Convert list of locations to list of trips
#
# ### 3a. Make trip IDs and list home-work and work-home modes by trip ID

# %%
def count_place(df):
    return df.join(df['place'].str.get_dummies()
                  .cumsum().add_suffix('_Count')).head(n=15)

trips = place5.groupby('HHPER', group_keys=False).apply(count_place)

trips.head()
# Out:
#        ET_num     HHPER   HHPERPLA      HXCORD     HYCORD  MODE  MODE_NEW  \
# 30   8.750000  10352742  103527421 -122.017274  37.388281   NaN       5.0
# 31  16.750000  10352742  103527422 -122.017274  37.388281   5.0       5.0
# 32  17.333333  10352742  103527423 -122.017274  37.388281   5.0       5.0
# 33  18.416667  10352742  103527424 -122.017274  37.388281   5.0       5.0
# 34  18.750000  10352742  103527425 -122.017274  37.388281   5.0       5.0
#
#                           PNAME     ST_num  WXCORD_lookup  WYCORD_lookup  \
# 30                         HOME   3.000000    -121.664242      37.151629
# 31                       EXELIS   9.166667    -121.664242      37.151629
# 32  REGENCY OF EVERGREEN VALLEY  17.083333    -121.664242      37.151629
# 33                          CVS  17.450000    -121.664242      37.151629
# 34  REGENCY OF EVERGREEN VALLEY  18.533333    -121.664242      37.151629
#
#     home_Count  no_Count place  work_Count  zone_id_home  zone_id_work
# 30         1.0       0.0  home           0           424         700.0
# 31         1.0       0.0  work           1           424         700.0
# 32         1.0       1.0    no           1           424         700.0
# 33         1.0       2.0    no           1           424         700.0
# 34         1.0       3.0    no           1           424         700.0

# %%
neverhome = trips[trips.home_Count.isnull()]

neverathome = neverhome.HHPER.unique()

neverhome.HHPER.nunique()
# Out:
# 34

# %%
trips = trips[~trips.HHPER.isin(neverathome)]

# %%
# personsnew3["home_Count"].fillna(0, inplace=True)

# personsnew3["no_Count"].fillna(0, inplace=True)

trips["trip_ID"] = trips["work_Count"].map(str) + trips["home_Count"].map(str)

trips["HHPERTRIP"] = trips["HHPER"].map(str) + trips["trip_ID"].map(str)

trips['count'] = trips.groupby('HHPERTRIP').cumcount() + 1

trips.head(n=20)
# Out:
#        ET_num     HHPER   HHPERPLA      HXCORD     HYCORD  MODE  MODE_NEW  \
# 30   8.750000  10352742  103527421 -122.017274  37.388281   NaN       5.0
# 31  16.750000  10352742  103527422 -122.017274  37.388281   5.0       5.0
# 32  17.333333  10352742  103527423 -122.017274  37.388281   5.0       5.0
# 33  18.416667  10352742  103527424 -122.017274  37.388281   5.0       5.0
# 34  18.750000  10352742  103527425 -122.017274  37.388281   5.0       5.0
# 35   2.983333  10352742  103527426 -122.017274  37.388281   5.0       NaN
# 65   8.500000  10414944  104149441 -122.091521  38.010760   NaN       5.0
# 66  17.500000  10414944  104149442 -122.091521  38.010760   5.0       5.0
# 67   2.983333  10414944  104149443 -122.091521  38.010760   5.0       NaN
# 68   8.000000  10417661  104176611 -122.414811  37.610585   NaN       5.0
# 69   8.666667  10417661  104176612 -122.414811  37.610585   5.0       5.0
# 70  17.500000  10417661  104176613 -122.414811  37.610585   5.0       5.0
# 71  18.166667  10417661  104176614 -122.414811  37.610585   5.0       5.0
# 72   2.983333  10417661  104176615 -122.414811  37.610585   5.0       NaN
# 73   8.000000  10417662  104176621 -122.414811  37.610585   NaN       5.0
# 74  18.500000  10417662  104176622 -122.414811  37.610585   5.0       5.0
# 75   2.983333  10417662  104176623 -122.414811  37.610585   5.0       NaN
# 79   8.250000  10436131  104361311 -122.252523  37.851942   NaN       5.0
# 80  12.083333  10436131  104361312 -122.252523  37.851942   5.0       5.0
# 81  13.466667  10436131  104361313 -122.252523  37.851942   5.0       5.0
#
#                             PNAME     ST_num  WXCORD_lookup  WYCORD_lookup  \
# 30                           HOME   3.000000    -121.664242      37.151629
# 31                         EXELIS   9.166667    -121.664242      37.151629
# 32    REGENCY OF EVERGREEN VALLEY  17.083333    -121.664242      37.151629
# 33                            CVS  17.450000    -121.664242      37.151629
# 34    REGENCY OF EVERGREEN VALLEY  18.533333    -121.664242      37.151629
# 35                           HOME  19.166667    -121.664242      37.151629
# 65                           HOME   3.000000    -122.118103      37.885783
# 66         INDEPENDENT CONTRACTOR   8.750000    -122.118103      37.885783
# 67                           HOME  18.000000    -122.118103      37.885783
# 68                           HOME   3.000000    -122.447100      37.779020
# 69     NATALIA SKATCHKOVA DAYCARE   8.500000    -122.447100      37.779020
# 70   BLOOD CENTERS OF THE PACIFIC   9.000000    -122.447100      37.779020
# 71     NATALIA SKATCHKOVA DAYCARE  18.000000    -122.447100      37.779020
# 72                           HOME  18.750000    -122.447100      37.779020
# 73                           HOME   3.000000    -122.328418      37.536798
# 74                     NEXTAG INC   8.500000    -122.328418      37.536798
# 75                           HOME  19.000000    -122.328418      37.536798
# 79                           HOME   3.000000    -122.275657      37.799656
# 80  ALAMEDA COUNTY SUPERIOR COURT   8.750000    -122.275657      37.799656
# 81                           HOME  12.400000    -122.275657      37.799656
#
#     home_Count  no_Count place  work_Count  zone_id_home  zone_id_work  \
# 30         1.0       0.0  home           0           424         700.0
# 31         1.0       0.0  work           1           424         700.0
# 32         1.0       1.0    no           1           424         700.0
# 33         1.0       2.0    no           1           424         700.0
# 34         1.0       3.0    no           1           424         700.0
# 35         2.0       3.0  home           1           424         700.0
# 65         1.0       NaN  home           0          1095        1152.0
# 66         1.0       NaN  work           1          1095        1152.0
# 67         2.0       NaN  home           1          1095        1152.0
# 68         1.0       0.0  home           0           241          69.0
# 69         1.0       1.0    no           0           241          69.0
# 70         1.0       1.0  work           1           241          69.0
# 71         1.0       2.0    no           1           241          69.0
# 72         2.0       2.0  home           1           241          69.0
# 73         1.0       NaN  home           0           241         282.0
# 74         1.0       NaN  work           1           241         282.0
# 75         2.0       NaN  home           1           241         282.0
# 79         1.0       0.0  home           0          1004         969.0
# 80         1.0       0.0  work           1          1004         969.0
# 81         2.0       0.0  home           1          1004         969.0
#
#    trip_ID     HHPERTRIP  count
# 30    01.0  1035274201.0      1
# 31    11.0  1035274211.0      1
# 32    11.0  1035274211.0      2
# 33    11.0  1035274211.0      3
# 34    11.0  1035274211.0      4
# 35    12.0  1035274212.0      1
# 65    01.0  1041494401.0      1
# 66    11.0  1041494411.0      1
# 67    12.0  1041494412.0      1
# 68    01.0  1041766101.0      1
# 69    01.0  1041766101.0      2
# 70    11.0  1041766111.0      1
# 71    11.0  1041766111.0      2
# 72    12.0  1041766112.0      1
# 73    01.0  1041766201.0      1
# 74    11.0  1041766211.0      1
# 75    12.0  1041766212.0      1
# 79    01.0  1043613101.0      1
# 80    11.0  1043613111.0      1
# 81    12.0  1043613112.0      1

# %%
trips['count'].max()
# Out:
# 14

# %%
trips1 = trips.pivot(index='HHPERTRIP', columns='count', values='MODE_NEW').reset_index()

trips1.columns = ['HHPERTRIP', 'MODE1', 'MODE2', 'MODE3', 'MODE4', 'MODE5', 'MODE6', 'MODE7', 
                       'MODE8', 'MODE9', 'MODE10', 'MODE11', 'MODE12', 'MODE13', 'MODE14']

trips1.head()
# Out:
#       HHPERTRIP  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  MODE7  MODE8  \
# 0  1035274201.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  1035274211.0    5.0    5.0    5.0    5.0    NaN    NaN    NaN    NaN
# 2  1035274212.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  1041494401.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  1041494411.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0    NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN     NaN     NaN     NaN     NaN     NaN
# 3    NaN     NaN     NaN     NaN     NaN     NaN
# 4    NaN     NaN     NaN     NaN     NaN     NaN

# %%
trips = pd.merge(trips, trips1, on='HHPERTRIP')

trips.head()
# Out:
#       ET_num     HHPER   HHPERPLA      HXCORD     HYCORD  MODE  MODE_NEW  \
# 0   8.750000  10352742  103527421 -122.017274  37.388281   NaN       5.0
# 1  16.750000  10352742  103527422 -122.017274  37.388281   5.0       5.0
# 2  17.333333  10352742  103527423 -122.017274  37.388281   5.0       5.0
# 3  18.416667  10352742  103527424 -122.017274  37.388281   5.0       5.0
# 4  18.750000  10352742  103527425 -122.017274  37.388281   5.0       5.0
#
#                          PNAME     ST_num  WXCORD_lookup  WYCORD_lookup  \
# 0                         HOME   3.000000    -121.664242      37.151629
# 1                       EXELIS   9.166667    -121.664242      37.151629
# 2  REGENCY OF EVERGREEN VALLEY  17.083333    -121.664242      37.151629
# 3                          CVS  17.450000    -121.664242      37.151629
# 4  REGENCY OF EVERGREEN VALLEY  18.533333    -121.664242      37.151629
#
#    home_Count  no_Count place  work_Count  zone_id_home  zone_id_work trip_ID  \
# 0         1.0       0.0  home           0           424         700.0    01.0
# 1         1.0       0.0  work           1           424         700.0    11.0
# 2         1.0       1.0    no           1           424         700.0    11.0
# 3         1.0       2.0    no           1           424         700.0    11.0
# 4         1.0       3.0    no           1           424         700.0    11.0
#
#       HHPERTRIP  count  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  MODE7  \
# 0  1035274201.0      1    5.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1  1035274211.0      1    5.0    5.0    5.0    5.0    NaN    NaN    NaN
# 2  1035274211.0      2    5.0    5.0    5.0    5.0    NaN    NaN    NaN
# 3  1035274211.0      3    5.0    5.0    5.0    5.0    NaN    NaN    NaN
# 4  1035274211.0      4    5.0    5.0    5.0    5.0    NaN    NaN    NaN
#
#    MODE8  MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# ### 3b. Isolate rows that identify start of home-work or work-home trips.

# %%
#List of all departures from home or work by workers.
homeworktrips = trips.loc[trips['place'].isin(["home","work"])]

# %%
homeworktrips['trip_ET'] = homeworktrips.groupby('HHPER', group_keys=False).ST_num.shift(-1)
# Out:
# /home/emma/anaconda/envs/ual-model/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
homeworktrips = homeworktrips[['HHPER', 'HHPERTRIP','place', 'ST_num','ET_num','trip_ET','MODE_NEW',
                               'zone_id_home','zone_id_work','HXCORD','HYCORD','WXCORD_lookup','WYCORD_lookup',
                               'MODE1', 'MODE2', 'MODE3', 'MODE4', 'MODE5', 'MODE6', 'MODE7', 
                           'MODE8', 'MODE9', 'MODE10', 'MODE11', 'MODE12', 'MODE13', 'MODE14']].copy()

homeworktrips.head(n=10)
# Out:
#        HHPER     HHPERTRIP place     ST_num     ET_num    trip_ET  MODE_NEW  \
# 0   10352742  1035274201.0  home   3.000000   8.750000   9.166667       5.0
# 1   10352742  1035274211.0  work   9.166667  16.750000  19.166667       5.0
# 5   10352742  1035274212.0  home  19.166667   2.983333        NaN       NaN
# 6   10414944  1041494401.0  home   3.000000   8.500000   8.750000       5.0
# 7   10414944  1041494411.0  work   8.750000  17.500000  18.000000       5.0
# 8   10414944  1041494412.0  home  18.000000   2.983333        NaN       NaN
# 9   10417661  1041766101.0  home   3.000000   8.000000   9.000000       5.0
# 11  10417661  1041766111.0  work   9.000000  17.500000  18.750000       5.0
# 13  10417661  1041766112.0  home  18.750000   2.983333        NaN       NaN
# 14  10417662  1041766201.0  home   3.000000   8.000000   8.500000       5.0
#
#     zone_id_home  zone_id_work      HXCORD     HYCORD  WXCORD_lookup  \
# 0            424         700.0 -122.017274  37.388281    -121.664242
# 1            424         700.0 -122.017274  37.388281    -121.664242
# 5            424         700.0 -122.017274  37.388281    -121.664242
# 6           1095        1152.0 -122.091521  38.010760    -122.118103
# 7           1095        1152.0 -122.091521  38.010760    -122.118103
# 8           1095        1152.0 -122.091521  38.010760    -122.118103
# 9            241          69.0 -122.414811  37.610585    -122.447100
# 11           241          69.0 -122.414811  37.610585    -122.447100
# 13           241          69.0 -122.414811  37.610585    -122.447100
# 14           241         282.0 -122.414811  37.610585    -122.328418
#
#     WYCORD_lookup  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  MODE7  MODE8  \
# 0       37.151629    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1       37.151629    5.0    5.0    5.0    5.0    NaN    NaN    NaN    NaN
# 5       37.151629    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6       37.885783    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7       37.885783    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8       37.885783    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9       37.779020    5.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN
# 11      37.779020    5.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN
# 13      37.779020    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 14      37.536798    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN     NaN     NaN     NaN
# 11    NaN     NaN     NaN     NaN     NaN     NaN
# 13    NaN     NaN     NaN     NaN     NaN     NaN
# 14    NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# ### 3c. Identify trips where the departure place is not the same as the one before it. This captures 'from home' trips that end at work and 'from work' trips that end at home.
#
# ### However, it also captures end-of-day 'from home' trips that don't end at work and 'from work' trips that don't end at home.

# %%
#Taking last trips where the place is not the same as the one before it and/or the person is not the same as the one before it.

tripsI = homeworktrips.loc[(homeworktrips.HHPER != homeworktrips.HHPER.shift(-1)) | (homeworktrips.place != homeworktrips.place.shift(-1))]

tripsI.head(n=10)
# Out:
#        HHPER     HHPERTRIP place     ST_num     ET_num    trip_ET  MODE_NEW  \
# 0   10352742  1035274201.0  home   3.000000   8.750000   9.166667       5.0
# 1   10352742  1035274211.0  work   9.166667  16.750000  19.166667       5.0
# 5   10352742  1035274212.0  home  19.166667   2.983333        NaN       NaN
# 6   10414944  1041494401.0  home   3.000000   8.500000   8.750000       5.0
# 7   10414944  1041494411.0  work   8.750000  17.500000  18.000000       5.0
# 8   10414944  1041494412.0  home  18.000000   2.983333        NaN       NaN
# 9   10417661  1041766101.0  home   3.000000   8.000000   9.000000       5.0
# 11  10417661  1041766111.0  work   9.000000  17.500000  18.750000       5.0
# 13  10417661  1041766112.0  home  18.750000   2.983333        NaN       NaN
# 14  10417662  1041766201.0  home   3.000000   8.000000   8.500000       5.0
#
#     zone_id_home  zone_id_work      HXCORD     HYCORD  WXCORD_lookup  \
# 0            424         700.0 -122.017274  37.388281    -121.664242
# 1            424         700.0 -122.017274  37.388281    -121.664242
# 5            424         700.0 -122.017274  37.388281    -121.664242
# 6           1095        1152.0 -122.091521  38.010760    -122.118103
# 7           1095        1152.0 -122.091521  38.010760    -122.118103
# 8           1095        1152.0 -122.091521  38.010760    -122.118103
# 9            241          69.0 -122.414811  37.610585    -122.447100
# 11           241          69.0 -122.414811  37.610585    -122.447100
# 13           241          69.0 -122.414811  37.610585    -122.447100
# 14           241         282.0 -122.414811  37.610585    -122.328418
#
#     WYCORD_lookup  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  MODE7  MODE8  \
# 0       37.151629    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1       37.151629    5.0    5.0    5.0    5.0    NaN    NaN    NaN    NaN
# 5       37.151629    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6       37.885783    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7       37.885783    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8       37.885783    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9       37.779020    5.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN
# 11      37.779020    5.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN
# 13      37.779020    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 14      37.536798    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN
# 7     NaN     NaN     NaN     NaN     NaN     NaN
# 8     NaN     NaN     NaN     NaN     NaN     NaN
# 9     NaN     NaN     NaN     NaN     NaN     NaN
# 11    NaN     NaN     NaN     NaN     NaN     NaN
# 13    NaN     NaN     NaN     NaN     NaN     NaN
# 14    NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# ### 3d. Identify end-of-day 'from home' trips that end at work, as well as end-of-day 'from work' trips that don't end at home.

# %%
#Identifying people whose last home or work location is work.

tripsJ = homeworktrips.loc[homeworktrips.HHPER != homeworktrips.HHPER.shift(-1)]

tripsJ.groupby(['place']).count()
# Out:
#        HHPER  HHPERTRIP  ST_num  ET_num  trip_ET  MODE_NEW  zone_id_home  \
# place
# home    6031       6031    6031    6031        0        80          6031
# work     146        146     146     146        0        65           146
#
#        zone_id_work  HXCORD  HYCORD  WXCORD_lookup  WYCORD_lookup  MODE1  \
# place
# home           6031    6031    6031           6031           6031     80
# work            146     146     146            146            146     65
#
#        MODE2  MODE3  MODE4  MODE5  MODE6  MODE7  MODE8  MODE9  MODE10  MODE11  \
# place
# home      50     31     16      6      4      2      1      1       1       0
# work      47     36     27     24     20     15      9      7       6       6
#
#        MODE12  MODE13  MODE14
# place
# home        0       0       0
# work        4       2       2

# %%
tripsK = tripsJ.loc[tripsJ['place'].isin(["work"])]

# %% [markdown]
# #### Ends day at work (night-shift workers). End-of-day 'from home' trip ends at work:

# %%
tripsL = tripsK[(tripsK['ET_num'] >= 2.98) & (tripsK['ET_num'] <= 2.985)]

nightshift = tripsL.HHPER.unique()

tripsL.HHPER.nunique()
# Out:
# 81

# %% [markdown]
# #### Leaves work but does not go home at end of day (to airport, second home, or another location). End-of-day 'from work' trip does not end at home:

# %%
tripsM = tripsK[(tripsK['ET_num'] <= 2.98) | (tripsK['ET_num'] >= 2.985)]

dontgohome = tripsM.HHPERTRIP.unique()

tripsM.HHPER.nunique()
# Out:
# 65

# %% [markdown]
# ### 3e. Get rid of last 'from home' trip for all those except night-shift workers, and get rid of last work activity for night-shift workers.

# %%
#Selecting all but people whose last 'from home' trip is to work. 
tripsII = tripsI[~tripsI.HHPER.isin(nightshift)] 

#Selecting people whose last 'from home' trip is to work.
tripsIII = tripsI[tripsI.HHPER.isin(nightshift)]

#Get rid of last work activity for nightshift workers.
tripsIII = tripsIII[(tripsIII['ET_num'] <= 2.9833) | (tripsIII['ET_num'] >= 2.9834)]

tripsIII.head()

print (tripsII.HHPER.nunique())

print (tripsIII.HHPER.nunique())
# Out:
# 6096
# 81

# %%
#Getting rid of last 'from home' trip for all those except people going to work.

tripsN = tripsII.groupby('HHPER').apply(lambda x: x.iloc[:-1] if (x.iloc[-1, x.columns.get_loc('place')] == "home") else x).reset_index(drop=True)

tripsN.HHPER.nunique()
# Out:
# 6095

# %%
#Adding back nine people going to work as last 'from home' trip.
tripsP = pd.concat([tripsN,tripsIII])

# %% [markdown]
# ### 3f. Identify people who go from home to work or from work to home more than once.

# %%
def count_place(df):
    return df.join(df['place'].str.get_dummies()
                  .cumsum().add_suffix('_Count')).head(n=15)

tripsP = tripsP.groupby('HHPER', group_keys=False).apply(count_place)

# %%
tripsP = tripsP[['HHPER', 'HHPERTRIP','place', 'home_Count','work_Count',
                 'ST_num','ET_num','trip_ET','MODE_NEW',
                 'zone_id_home','zone_id_work','HXCORD','HYCORD','WXCORD_lookup','WYCORD_lookup',
                               'MODE1', 'MODE2', 'MODE3', 'MODE4', 'MODE5', 'MODE6', 'MODE7', 
                           'MODE8', 'MODE9', 'MODE10', 'MODE11', 'MODE12', 'MODE13', 'MODE14']].copy()

tripsP.head()
# Out:
#       HHPER     HHPERTRIP place  home_Count  work_Count    ST_num  ET_num  \
# 0  10352742  1035274201.0  home         1.0         0.0  3.000000    8.75
# 1  10352742  1035274211.0  work         1.0         1.0  9.166667   16.75
# 2  10414944  1041494401.0  home         1.0         0.0  3.000000    8.50
# 3  10414944  1041494411.0  work         1.0         1.0  8.750000   17.50
# 4  10417661  1041766101.0  home         1.0         0.0  3.000000    8.00
#
#      trip_ET  MODE_NEW  zone_id_home  zone_id_work      HXCORD     HYCORD  \
# 0   9.166667       5.0           424         700.0 -122.017274  37.388281
# 1  19.166667       5.0           424         700.0 -122.017274  37.388281
# 2   8.750000       5.0          1095        1152.0 -122.091521  38.010760
# 3  18.000000       5.0          1095        1152.0 -122.091521  38.010760
# 4   9.000000       5.0           241          69.0 -122.414811  37.610585
#
#    WXCORD_lookup  WYCORD_lookup  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  \
# 0    -121.664242      37.151629    5.0    NaN    NaN    NaN    NaN    NaN
# 1    -121.664242      37.151629    5.0    5.0    5.0    5.0    NaN    NaN
# 2    -122.118103      37.885783    5.0    NaN    NaN    NaN    NaN    NaN
# 3    -122.118103      37.885783    5.0    NaN    NaN    NaN    NaN    NaN
# 4    -122.447100      37.779020    5.0    5.0    NaN    NaN    NaN    NaN
#
#    MODE7  MODE8  MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN

# %%
workweird1 = tripsP.groupby('HHPER').filter(lambda x : x['home_Count'].isin(["2"]).any())

workweird1a = workweird1.HHPER.unique()

workweird2 = tripsP.groupby('HHPER').filter(lambda x : x['work_Count'].isin(["2"]).any())

workweird2a = workweird2.HHPER.unique()

print (workweird1.HHPER.nunique())
print (workweird2.HHPER.nunique())
print (tripsP.HHPER.nunique())
# Out:
# 261
# 264
# 6176

# %%
tripsP = tripsP[~tripsP.HHPER.isin(workweird1a)] 

tripsP = tripsP[~tripsP.HHPER.isin(workweird2a)] 

tripsP.HHPER.nunique()
# Out:
# 5908

# %% [markdown]
# ### 3g. Add columns with dwell time at the origin and travel time to arrival location.

# %%
tripsP['origin_ST'] = tripsP.groupby('HHPER', group_keys=False).trip_ET.shift(+1)

# %%
ZZ = tripsP['trip_ET'].groupby(tripsP['HHPER']).apply(lambda x: x.iloc[-1]).reset_index()

ZZ.columns = ['HHPER','last_tt']

ZZ.head()
# Out:
#       HHPER    last_tt
# 0  10352742  19.166667
# 1  10414944  18.000000
# 2  10417661  18.750000
# 3  10417662  19.000000
# 4  10436132  19.400000

# %%
tripsP = pd.merge(tripsP, ZZ, on='HHPER')

# %%
#Identify people who don't start and end day in same location (so can't assume equivalent schedules day-to-day).

nonparallel1 = place3['PNAME'].groupby(place3['HHPER']).apply(lambda x: x.iloc[0]).reset_index()

nonparallel1.columns = ['HHPER','first_place']

nonparallel2 = place3['PNAME'].groupby(place3['HHPER']).apply(lambda x: x.iloc[-1]).reset_index()

nonparallel2.columns = ['HHPER','last_place']

nonparallel = pd.merge(nonparallel1, nonparallel2, on='HHPER')

nonparallel = nonparallel.loc[nonparallel['first_place']!=nonparallel['last_place']]

nonparallelIDs = nonparallel.HHPER.unique()

# %%
tripsPa = tripsP[~tripsP.HHPER.isin(nonparallelIDs)] 
tripsPb = tripsP[tripsP.HHPER.isin(nonparallelIDs)]

# %%
tripsPa["origin_ST"].fillna(tripsPa['last_tt'], inplace=True)

tripsPa.head()
# Out:
# /home/emma/anaconda/envs/ual-model/lib/python3.6/site-packages/pandas/core/generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#       HHPER     HHPERTRIP place  home_Count  work_Count    ST_num  ET_num  \
# 0  10352742  1035274201.0  home         1.0         0.0  3.000000    8.75
# 1  10352742  1035274211.0  work         1.0         1.0  9.166667   16.75
# 2  10414944  1041494401.0  home         1.0         0.0  3.000000    8.50
# 3  10414944  1041494411.0  work         1.0         1.0  8.750000   17.50
# 4  10417661  1041766101.0  home         1.0         0.0  3.000000    8.00
#
#      trip_ET  MODE_NEW  zone_id_home  zone_id_work      HXCORD     HYCORD  \
# 0   9.166667       5.0           424         700.0 -122.017274  37.388281
# 1  19.166667       5.0           424         700.0 -122.017274  37.388281
# 2   8.750000       5.0          1095        1152.0 -122.091521  38.010760
# 3  18.000000       5.0          1095        1152.0 -122.091521  38.010760
# 4   9.000000       5.0           241          69.0 -122.414811  37.610585
#
#    WXCORD_lookup  WYCORD_lookup  MODE1  MODE2  MODE3  MODE4  MODE5  MODE6  \
# 0    -121.664242      37.151629    5.0    NaN    NaN    NaN    NaN    NaN
# 1    -121.664242      37.151629    5.0    5.0    5.0    5.0    NaN    NaN
# 2    -122.118103      37.885783    5.0    NaN    NaN    NaN    NaN    NaN
# 3    -122.118103      37.885783    5.0    NaN    NaN    NaN    NaN    NaN
# 4    -122.447100      37.779020    5.0    5.0    NaN    NaN    NaN    NaN
#
#    MODE7  MODE8  MODE9  MODE10  MODE11  MODE12  MODE13  MODE14  origin_ST  \
# 0    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN  19.166667
# 1    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN   9.166667
# 2    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN  18.000000
# 3    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN   8.750000
# 4    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN  18.750000
#
#      last_tt
# 0  19.166667
# 1  19.166667
# 2  18.000000
# 3  18.000000
# 4  18.750000

# %%
tripsP = pd.concat([tripsPa,tripsPb])

# %%
tripsP["origin_dwell"] = tripsP["ET_num"] - tripsP["origin_ST"]

tripsP.loc[ (tripsP['origin_dwell'] < 0),
    'origin_dwell'] = tripsP['origin_dwell'] + 24

# %%
tripsP['TT'] = tripsP['trip_ET'] - tripsP['ET_num']

tripsP.loc[ (tripsP['TT'] < 0),
    'TT'] = tripsP['TT'] + 24

# %%
tripsW = tripsP.loc[(tripsP['origin_dwell'] + tripsP['TT']) == 24]

tripsW.HHPER.nunique()
# Out:
# 1

# %%
tripsP.loc[(tripsP['origin_dwell'] + tripsP['TT']) == 24,
           'origin_dwell'] = np.NaN

# %%
tripsP=tripsP.rename(columns = {'place':'origin','ET_num':'origin_ET','WXCORD_lookup':'WXCORD','WYCORD_lookup':'WYCORD'})

# %%
trips3 = tripsP[['HHPER', 'HHPERTRIP','origin',
                 'origin_dwell','origin_ST','origin_ET','trip_ET','TT',
                 'zone_id_home','zone_id_work','HXCORD','HYCORD','WXCORD','WYCORD',
                               'MODE1', 'MODE2', 'MODE3', 'MODE4', 'MODE5', 'MODE6', 'MODE7', 
                           'MODE8', 'MODE9', 'MODE10', 'MODE11', 'MODE12', 'MODE13', 'MODE14']].copy()

# %%
trips3['Oxcord'] = np.where(trips3['origin'] == "home", trips3['HXCORD'], 'no')

trips3.loc[trips3.origin == "work", 'Oxcord'] = trips3['WXCORD']

trips3['Oycord'] = np.where(trips3['origin'] == "home", trips3['HYCORD'], 'no')

trips3.loc[trips3.origin == "work", 'Oycord'] = trips3['WYCORD']

trips3['Dxcord'] = np.where(trips3['origin'] == "home", trips3['WXCORD'], 'no')

trips3.loc[trips3.origin == "work", 'Dxcord'] = trips3['HXCORD']

trips3['Dycord'] = np.where(trips3['origin'] == "home", trips3['WYCORD'], 'no')

trips3.loc[trips3.origin == "work", 'Dycord'] = trips3['HYCORD']

trips3['Ozone'] = np.where(trips3['origin'] == "home", trips3['zone_id_home'], 'no')

trips3.loc[trips3.origin == "work", 'Ozone'] = trips3['zone_id_work']

trips3['Dzone'] = np.where(trips3['origin'] == "home", trips3['zone_id_work'], 'no')

trips3.loc[trips3.origin == "work", 'Dzone'] = trips3['zone_id_home']

# %%
tripsR = trips3[['HHPER', 'HHPERTRIP','origin',
                 'origin_dwell','origin_ST','origin_ET','trip_ET','TT',
                 'Ozone','Dzone','Oxcord','Oycord','Dxcord','Dycord',
                               'MODE1', 'MODE2', 'MODE3', 'MODE4', 'MODE5', 'MODE6', 'MODE7', 
                           'MODE8', 'MODE9', 'MODE10', 'MODE11', 'MODE12', 'MODE13', 'MODE14']].copy()

# %%
tripsR.head()
# Out:
#       HHPER     HHPERTRIP origin  origin_dwell  origin_ST  origin_ET  \
# 0  10352742  1035274201.0   home     13.583333  19.166667       8.75
# 1  10352742  1035274211.0   work      7.583333   9.166667      16.75
# 2  10414944  1041494401.0   home     14.500000  18.000000       8.50
# 3  10414944  1041494411.0   work      8.750000   8.750000      17.50
# 4  10417661  1041766101.0   home     13.250000  18.750000       8.00
#
#      trip_ET        TT Ozone   Dzone               Oxcord     Oycord  \
# 0   9.166667  0.416667   424   700.0          -122.017274  37.388281
# 1  19.166667  2.416667   700     424             -121.664    37.1516
# 2   8.750000  0.250000  1095  1152.0          -122.091521   38.01076
# 3  18.000000  0.500000  1152    1095             -122.118    37.8858
# 4   9.000000  1.000000   241    69.0  -122.41481100000001  37.610585
#
#                 Dxcord              Dycord  MODE1  MODE2  MODE3  MODE4  MODE5  \
# 0  -121.66424170000002          37.1516286    5.0    NaN    NaN    NaN    NaN
# 1             -122.017             37.3883    5.0    5.0    5.0    5.0    NaN
# 2         -122.1181031  37.885783399999994    5.0    NaN    NaN    NaN    NaN
# 3             -122.092             38.0108    5.0    NaN    NaN    NaN    NaN
# 4  -122.44709979999999  37.779019899999994    5.0    5.0    NaN    NaN    NaN
#
#    MODE6  MODE7  MODE8  MODE9  MODE10  MODE11  MODE12  MODE13  MODE14
# 0    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# ## Step 4. Assign modes: drive alone, shared, bike, walk, walkTransitwalk, driveTransitwalk, walkTransitdrive.

# %%
tripsR['MODE'] = np.where((((tripsR['MODE1'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE2'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE3'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE4'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE5'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE6'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE7'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE8'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE9'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE10'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE11'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE12'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE13'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE14'].isin([5.0,6.0,7.0,8.0,9.0,10.0]))) &
                            ((tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])))),
                          'drive_transit','no')

# %%
tripsR.loc[((tripsR['MODE']== 'drive_transit') & (tripsR['origin'] == 'work')),
           'MODE'] = 'WTranDr'

tripsR.loc[((tripsR['MODE']== 'drive_transit') & (tripsR['origin'] == 'home')),
           'MODE'] = 'DrTranW'

# %%
tripsR.loc[(((tripsR['MODE1'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE2'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE3'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE4'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE5'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE6'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE7'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE8'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE9'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE10'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE11'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE12'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE13'].isin([5.0,8.0,9.0,10.0])) |
                                                           (tripsR['MODE14'].isin([5.0,8.0,9.0,10.0]))) &
                            ((~tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])))),
           'MODE'] = 'drive_alone'

# %%
tripsR.loc[(((tripsR['MODE1'].isin([6.0,7.0])) |
                                                           (tripsR['MODE2'].isin([6.0,7.0])) |
                                                           (tripsR['MODE3'].isin([6.0,7.0])) |
                                                           (tripsR['MODE4'].isin([6.0,7.0])) |
                                                           (tripsR['MODE5'].isin([6.0,7.0])) |
                                                           (tripsR['MODE6'].isin([6.0,7.0])) |
                                                           (tripsR['MODE7'].isin([6.0,7.0])) |
                                                           (tripsR['MODE8'].isin([6.0,7.0])) |
                                                           (tripsR['MODE9'].isin([6.0,7.0])) |
                                                           (tripsR['MODE10'].isin([6.0,7.0])) |
                                                           (tripsR['MODE11'].isin([6.0,7.0])) |
                                                           (tripsR['MODE12'].isin([6.0,7.0])) |
                                                           (tripsR['MODE13'].isin([6.0,7.0])) |
                                                           (tripsR['MODE14'].isin([6.0,7.0]))) &
                            ((~tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])))),
           'MODE'] = 'shared'

# %%
tripsR.loc[(((~tripsR['MODE1'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE2'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE3'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE4'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE5'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE6'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE7'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE8'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE9'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE10'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE11'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE12'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE13'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE14'].isin([5.0,6.0,7.0,8.0,9.0,10.0]))) &
                            ((tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) |
                             (tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0]))) &
           ((tripsR['MODE1'].isin([1.0])) |
            (tripsR['MODE2'].isin([1.0])) |
            (tripsR['MODE3'].isin([1.0])) |
            (tripsR['MODE4'].isin([1.0])) |
            (tripsR['MODE5'].isin([1.0])) |
            (tripsR['MODE6'].isin([1.0])) |
            (tripsR['MODE7'].isin([1.0])) |
            (tripsR['MODE8'].isin([1.0])) |
            (tripsR['MODE9'].isin([1.0])) |
            (tripsR['MODE10'].isin([1.0])) |
            (tripsR['MODE11'].isin([1.0])) |
            (tripsR['MODE12'].isin([1.0])) |
            (tripsR['MODE13'].isin([1.0])) |
            (tripsR['MODE14'].isin([1.0])))),
           'MODE'] = 'WTranW'

# %%
tripsR.loc[(((~tripsR['MODE1'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE2'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE3'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE4'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE5'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE6'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE7'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE8'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE9'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE10'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE11'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE12'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE13'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE14'].isin([5.0,6.0,7.0,8.0,9.0,10.0]))) &
                            ((~tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0]))) &
            ((tripsR['MODE1'].isin([2.0])) |
            (tripsR['MODE2'].isin([2.0])) |
            (tripsR['MODE3'].isin([2.0])) |
            (tripsR['MODE4'].isin([2.0])) |
            (tripsR['MODE5'].isin([2.0])) |
            (tripsR['MODE6'].isin([2.0])) |
            (tripsR['MODE7'].isin([2.0])) |
            (tripsR['MODE8'].isin([2.0])) |
            (tripsR['MODE9'].isin([2.0])) |
            (tripsR['MODE10'].isin([2.0])) |
            (tripsR['MODE11'].isin([2.0])) |
            (tripsR['MODE12'].isin([2.0])) |
            (tripsR['MODE13'].isin([2.0])) |
            (tripsR['MODE14'].isin([2.0])))), 'MODE'] = 'bike'

# %%
tripsR.loc[(((~tripsR['MODE1'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE2'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE3'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE4'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE5'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE6'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE7'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE8'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE9'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE10'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE11'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE12'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE13'].isin([5.0,6.0,7.0,8.0,9.0,10.0])) &
                                                           (~tripsR['MODE14'].isin([5.0,6.0,7.0,8.0,9.0,10.0]))) &
                            ((~tripsR['MODE1'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE2'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE3'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE4'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE5'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE6'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE7'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE8'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE9'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE10'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE11'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE12'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE13'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0])) &
                             (~tripsR['MODE14'].isin([15.0,16.0,17.0,19.0,20.0,21.0,22.0,23.0,24.0,25.0,26.0,27.0,28.0,29.0]))) &
            ((~tripsR['MODE1'].isin([2.0])) &
            (~tripsR['MODE2'].isin([2.0])) &
            (~tripsR['MODE3'].isin([2.0])) &
            (~tripsR['MODE4'].isin([2.0])) &
            (~tripsR['MODE5'].isin([2.0])) &
            (~tripsR['MODE6'].isin([2.0])) &
            (~tripsR['MODE7'].isin([2.0])) &
            (~tripsR['MODE8'].isin([2.0])) &
            (~tripsR['MODE9'].isin([2.0])) &
            (~tripsR['MODE10'].isin([2.0])) &
            (~tripsR['MODE11'].isin([2.0])) &
            (~tripsR['MODE12'].isin([2.0])) &
            (~tripsR['MODE13'].isin([2.0])) &
            (~tripsR['MODE14'].isin([2.0]))) &
            ((tripsR['MODE1'].isin([1.0])) |
            (tripsR['MODE2'].isin([1.0])) |
            (tripsR['MODE3'].isin([1.0])) |
            (tripsR['MODE4'].isin([1.0])) |
            (tripsR['MODE5'].isin([1.0])) |
            (tripsR['MODE6'].isin([1.0])) |
            (tripsR['MODE7'].isin([1.0])) |
            (tripsR['MODE8'].isin([1.0])) |
            (tripsR['MODE9'].isin([1.0])) |
            (tripsR['MODE10'].isin([1.0])) |
            (tripsR['MODE11'].isin([1.0])) |
            (tripsR['MODE12'].isin([1.0])) |
            (tripsR['MODE13'].isin([1.0])) |
            (tripsR['MODE14'].isin([1.0])))), 'MODE'] = 'walk'

# %%
tripsR.head(n=25)
# Out:
#        HHPER     HHPERTRIP origin  origin_dwell  origin_ST  origin_ET  \
# 0   10352742  1035274201.0   home     13.583333  19.166667   8.750000
# 1   10352742  1035274211.0   work      7.583333   9.166667  16.750000
# 2   10414944  1041494401.0   home     14.500000  18.000000   8.500000
# 3   10414944  1041494411.0   work      8.750000   8.750000  17.500000
# 4   10417661  1041766101.0   home     13.250000  18.750000   8.000000
# 5   10417661  1041766111.0   work      8.500000   9.000000  17.500000
# 6   10417662  1041766201.0   home     13.000000  19.000000   8.000000
# 7   10417662  1041766211.0   work     10.000000   8.500000  18.500000
# 8   10436132  1043613201.0   home     11.866667  19.400000   7.266667
# 9   10436132  1043613221.0   work     11.133333   7.866667  19.000000
# 10  10456071  1045607101.0   home     13.416667  16.916667   6.333333
# 11  10456071  1045607111.0   work      8.250000   7.000000  15.250000
# 12  10456721  1045672101.0   home     13.050000  18.166667   7.216667
# 13  10456721  1045672111.0   work      9.200000   8.050000  17.250000
# 14  10456723  1045672301.0   home     14.000000  17.500000   7.500000
# 15  10456723  1045672311.0   work      9.000000   8.000000  17.000000
# 16  10488521  1048852101.0   home     12.583333  18.916667   7.500000
# 17  10488521  1048852111.0   work      8.283333   8.716667  17.000000
# 18  10499081  1049908101.0   home     14.750000  13.250000   4.000000
# 19  10499081  1049908111.0   work      8.750000   4.250000  13.000000
# 20  10513882  1051388201.0   home     16.500000  15.516667   8.016667
# 21  10513882  1051388211.0   work      6.083333   8.583333  14.666667
# 22  10554492  1055449201.0   home     20.083333  17.583333  13.666667
# 23  10554492  1055449211.0   work      3.166667  13.833333  17.000000
# 24  10591841  1059184101.0   home     14.000000  17.500000   7.500000
#
#       trip_ET        TT Ozone   Dzone               Oxcord  \
# 0    9.166667  0.416667   424   700.0          -122.017274
# 1   19.166667  2.416667   700     424             -121.664
# 2    8.750000  0.250000  1095  1152.0          -122.091521
# 3   18.000000  0.500000  1152    1095             -122.118
# 4    9.000000  1.000000   241    69.0  -122.41481100000001
# 5   18.750000  1.250000    69     241             -122.447
# 6    8.500000  0.500000   241   282.0  -122.41481100000001
# 7   19.000000  0.500000   282     241             -122.328
# 8    7.866667  0.600000  1004  1127.0  -122.25252320000001
# 9   19.400000  0.400000  1127    1004              -122.07
# 10   7.000000  0.666667   908   116.0          -122.189451
# 11  16.916667  1.666667   116     908             -122.411
# 12   8.050000  0.833333  1100   971.0           -121.94335
# 13  18.166667  0.916667   971    1100             -122.265
# 14   8.000000  0.500000  1100  1122.0           -121.94335
# 15  17.500000  0.500000  1122    1100             -122.054
# 16   8.716667  1.216667  1145  1020.0  -122.05665400000001
# 17  18.916667  1.916667  1020    1145             -122.258
# 18   4.250000  0.250000    30    12.0         -122.4181131
# 19  13.250000  0.250000    12      30             -122.402
# 20   8.583333  0.566667    89     4.0         -122.4457731
# 21  15.516667  0.850000     4      89             -122.402
# 22  13.833333  0.166667  1360  1359.0          -122.710948
# 23  17.583333  0.583333  1359    1360             -122.698
# 24   8.000000  0.500000   722   742.0          -121.783657
#
#                 Oycord               Dxcord              Dycord  MODE1  MODE2  \
# 0            37.388281  -121.66424170000002          37.1516286    5.0    NaN
# 1              37.1516             -122.017             37.3883    5.0    5.0
# 2             38.01076         -122.1181031  37.885783399999994    5.0    NaN
# 3              37.8858             -122.092             38.0108    5.0    NaN
# 4            37.610585  -122.44709979999999  37.779019899999994    5.0    5.0
# 5               37.779             -122.415             37.6106    5.0    5.0
# 6            37.610585          -122.328418           37.536798    5.0    NaN
# 7              37.5368             -122.415             37.6106    5.0    NaN
# 8   37.851941700000005  -122.06999309999999          37.9694722    5.0    5.0
# 9              37.9695             -122.253             37.8519    5.0    NaN
# 10          37.7906644         -122.4107611   37.75957879999999    7.0    NaN
# 11             37.7596             -122.189             37.7907    1.0   15.0
# 12  37.953765000000004  -122.26538529999999          37.8063078    5.0   24.0
# 13             37.8063             -121.943             37.9538    1.0   24.0
# 14  37.953765000000004          -122.053556  37.976257000000004    5.0    NaN
# 15             37.9763             -121.943             37.9538    5.0    NaN
# 16           37.901733  -122.25838759999999  37.874711100000006    1.0   15.0
# 17             37.8747             -122.057             37.9017    1.0   23.0
# 18          37.7865471         -122.4016528          37.7888576    2.0    NaN
# 19             37.7889             -122.418             37.7865    2.0    NaN
# 20   37.76727929999999  -122.40196270000001  37.789679799999995    5.0    5.0
# 21             37.7897             -122.446             37.7673    1.0    5.0
# 22           38.434959  -122.69826299999998           38.443227    5.0    NaN
# 23             38.4432             -122.711              38.435    5.0    5.0
# 24           37.690989         -121.8954747          37.6915014    5.0    NaN
#
#     MODE3  MODE4  MODE5  MODE6  MODE7  MODE8  MODE9  MODE10  MODE11  MODE12  \
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 1     5.0    5.0    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 5     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 6     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 7     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 8     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 9     NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 10    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 11   15.0   22.0   25.0    1.0    NaN    NaN    NaN     NaN     NaN     NaN
# 12    1.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 13    5.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 14    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 15    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 16   24.0   24.0    1.0   23.0    1.0    NaN    NaN     NaN     NaN     NaN
# 17    1.0   24.0   24.0   15.0    1.0    NaN    NaN     NaN     NaN     NaN
# 18    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 19    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 20    1.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 21    5.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 22    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 23    5.0    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 24    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
#
#     MODE13  MODE14         MODE
# 0      NaN     NaN  drive_alone
# 1      NaN     NaN  drive_alone
# 2      NaN     NaN  drive_alone
# 3      NaN     NaN  drive_alone
# 4      NaN     NaN  drive_alone
# 5      NaN     NaN  drive_alone
# 6      NaN     NaN  drive_alone
# 7      NaN     NaN  drive_alone
# 8      NaN     NaN  drive_alone
# 9      NaN     NaN  drive_alone
# 10     NaN     NaN       shared
# 11     NaN     NaN       WTranW
# 12     NaN     NaN      DrTranW
# 13     NaN     NaN      WTranDr
# 14     NaN     NaN  drive_alone
# 15     NaN     NaN  drive_alone
# 16     NaN     NaN       WTranW
# 17     NaN     NaN       WTranW
# 18     NaN     NaN         bike
# 19     NaN     NaN         bike
# 20     NaN     NaN  drive_alone
# 21     NaN     NaN  drive_alone
# 22     NaN     NaN  drive_alone
# 23     NaN     NaN  drive_alone
# 24     NaN     NaN  drive_alone

# %%
strange_mode = tripsR[tripsR.MODE == "no"]

strange_mode.HHPER.nunique()
# Out:
# 71

# %%
strange_mode.MODE1.unique()
# Out:
# array([ 2.,  4., 11.,  3., 21., 14., 29., 24., 18.])

# %%
#Get rid of strange-mode trips
tripsR = tripsR[tripsR.MODE != "no"]

# %%
tripsU = tripsR[['HHPER', 'HHPERTRIP','origin', 'origin_dwell',
 'origin_ST',
 'origin_ET',
 'trip_ET',
 'TT',
 'Ozone',
 'Dzone',
 'Oxcord',
 'Oycord',
 'Dxcord',
 'Dycord','MODE']].copy()

tripsU.head()
# Out:
#       HHPER     HHPERTRIP origin  origin_dwell  origin_ST  origin_ET  \
# 0  10352742  1035274201.0   home     13.583333  19.166667       8.75
# 1  10352742  1035274211.0   work      7.583333   9.166667      16.75
# 2  10414944  1041494401.0   home     14.500000  18.000000       8.50
# 3  10414944  1041494411.0   work      8.750000   8.750000      17.50
# 4  10417661  1041766101.0   home     13.250000  18.750000       8.00
#
#      trip_ET        TT Ozone   Dzone               Oxcord     Oycord  \
# 0   9.166667  0.416667   424   700.0          -122.017274  37.388281
# 1  19.166667  2.416667   700     424             -121.664    37.1516
# 2   8.750000  0.250000  1095  1152.0          -122.091521   38.01076
# 3  18.000000  0.500000  1152    1095             -122.118    37.8858
# 4   9.000000  1.000000   241    69.0  -122.41481100000001  37.610585
#
#                 Dxcord              Dycord         MODE
# 0  -121.66424170000002          37.1516286  drive_alone
# 1             -122.017             37.3883  drive_alone
# 2         -122.1181031  37.885783399999994  drive_alone
# 3             -122.092             38.0108  drive_alone
# 4  -122.44709979999999  37.779019899999994  drive_alone

# %%
# tripsU.loc[ (tripsU['origin_ST'] > 24),
#     'origin_ST'] = tripsU['origin_ST'] - 24

# tripsU.loc[ (tripsU['origin_ET'] > 24),
#     'origin_ET'] = tripsU['origin_ET'] - 24

# tripsU.loc[ (tripsU['trip_ET'] > 24),
#     'trip_ET'] = tripsU['trip_ET'] - 24

# %%
tripsU.describe()
# Out:
#        origin_dwell     origin_ST     origin_ET       trip_ET            TT
# count  11389.000000  11390.000000  11597.000000  11538.000000  11538.000000
# mean      11.015739     13.247398     12.455134     13.280093      0.941638
# std        3.886960      5.191652      4.979629      5.197063      1.165347
# min        0.033333      0.016667      0.016667      0.016667      0.016667
# 25%        8.500000      8.333333      7.683333      8.366667      0.333333
# 50%       10.683333     13.500000     12.666667     13.683333      0.583333
# 75%       13.833333     18.000000     17.000000     18.000000      1.000000
# max       23.416667     24.000000     24.000000     24.000000     13.816667

# %%
# tripsYY = tripsU[tripsU['HHPER'].isin(nonparallelIDs)]

# tripsYY.HHPER.nunique()

# %%
# tripsYY.head(n=15)

# %%
# nulls = tripsU[pd.isnull(tripsU).any(axis=1)]

# nulls.HHPER.nunique()

# %%
# tripsX = nulls[~nulls['HHPER'].isin(nonparallelIDs)]

# XX = tripsX.HHPER.unique()

# %%
# place3[place3['HHPER'].isin(XX)]

# %%
# tripsX.head(n=25)

# %%
long = tripsU.loc[(tripsU['origin_dwell'] > 20) & (tripsU['origin'] == 'work')]

long2 = long.HHPER.unique()

odd = place3[place3.HHPER.isin(long2)]

odd.HHPER.nunique()
# Out:
# 0

# %%
tripsU = tripsU[~(tripsU['HHPER'].isin(long2))]

# %%
tripsU.to_csv('HWtrips_101418.csv')
